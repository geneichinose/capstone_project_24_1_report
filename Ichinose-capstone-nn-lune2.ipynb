# %% [markdown]
# ## Use NN to create a classifier
#
# Moment tensor based multinomial classifier for Earthquake, Explosion, and Mine/Cavity Collapse targets.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow_addons as tfa

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Activation, Dropout
from tensorflow.math import confusion_matrix
from tensorflow.keras.metrics import Recall, CategoricalAccuracy, Precision

from keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow_addons.metrics import F1Score

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay

import pickle

import warnings
from sklearn import set_config
set_config(display="diagram")
warnings.filterwarnings('ignore')
# Out:
# 2023-03-08 21:36:50.309745: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# run this only once in the beginning so that the classifier does not change and the results are reproducible

# %%
seed = 111111
tf.random.set_seed(seed)

# %% [markdown]
# read in the data

# %%
df = pd.read_csv( "data/ML_mt_geysers.csv")

# %% [markdown]
# map the numerical label column to string label based on event dictionary

# %%
event_dict = { 0:'eq', 1:'ex', 2:'co' }
df['etype'] = df['label'].map(event_dict)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1440 entries, 0 to 1439
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   lune_lon     1440 non-null   float64
#  1   lune_lat     1440 non-null   float64
#  2   pvr          1440 non-null   float64
#  3   pdc          1440 non-null   int64
#  4   pclvd        1440 non-null   int64
#  5   piso         1440 non-null   int64
#  6   Mo           1440 non-null   float64
#  7   mxx          1440 non-null   float64
#  8   myy          1440 non-null   float64
#  9   mzz          1440 non-null   float64
#  10  mxy          1440 non-null   float64
#  11  mxz          1440 non-null   float64
#  12  myz          1440 non-null   float64
#  13  eig1         1440 non-null   float64
#  14  eig2         1440 non-null   float64
#  15  eig3         1440 non-null   float64
#  16  origin_time  1440 non-null   object
#  17  lat          1440 non-null   float64
#  18  lon          1440 non-null   float64
#  19  momag        1440 non-null   float64
#  20  depth        1440 non-null   float64
#  21  evid         1440 non-null   int64
#  22  auth         1440 non-null   object
#  23  region       1440 non-null   object
#  24  label        1440 non-null   int64
#  25  etype        1440 non-null   object
# dtypes: float64(17), int64(5), object(4)
# memory usage: 292.6+ KB

# %% [markdown]
# The selected features are the lune parameters lune_lat, lune_lon a spherical projection of the eigenvalues of the moment tensor

# %%
features_lune = ['lune_lat', 'lune_lon']
# features_mt = ['mxx', 'myy', 'mzz', 'mxy', 'mxz', 'myz']
# X = df[features_mt]
X = df[features_lune]
y =  df[['label']]
print(X.shape, y.shape)
# Out:
# (1440, 2) (1440, 1)

# %% [markdown]
# For tensorflow keras use label binarizer to one-hot encode the target

# %%
lb = LabelBinarizer()
y_ohe = lb.fit_transform(y)

# %%
# y_ohe[1400:1420,:]
# y[1400:1420]
# lb.inverse_transform(y_ohe[1400:1420,:])
# y_ohe.shape

# %% [markdown]
# Since the dataset is small (1400 values), then we made a larger 40% test set.
# This is the same split used by other notebook ichinose-capstone-version4.ipynb

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y_ohe, test_size=0.4, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (864, 2)
# (576, 2)
# (864, 3)
# (576, 3)

# %% [markdown]
# ### We created a simple 2 neuron input layer,  1 layer - 2 neuron hidden layer with sigmoid activation function, and softmax output layer (3 classes).
#
# Recall is the metric which we wanted to use based on bussiness choice but this lead to a lot of false alarms.  We decided to use f1-score as a balance between precision and recall.  We used batch normalization for faster convergence.

# %%
# Dense(  2, input_dim=2, use_bias = False, activation='sigmoid'),
#   Activation("sigmoid"),
# Dropout( rate = 0.25 ),

model1 = Sequential([
    Dense(  2, input_dim=2, use_bias = False, activation="sigmoid" ),
    BatchNormalization(),
    Dense(  3, activation="softmax"),
])

callback = EarlyStopping(monitor='loss', patience = 20, min_delta = 0.00001, verbose = 1)

# "SGD"
# optim = SGD(learning_rate=0.001)
# "adam"
optim = Adam(learning_rate=0.005)
# "RMSprop"
# optim = RMSprop( learning_rate=0.001 )

# metrics = CategoricalAccuracy( name="categorical_accuracy")
# metrics = Precision( thresholds=0.5, name="precision" )
# metrics = Recall( thresholds = 0.5, class_id=1, top_k=3, name="recall" )
# metrics = Recall( thresholds = 0.5, name="recall" )
metrics = F1Score( num_classes=3, threshold=0.5, name="f1-score", average="weighted" )

# %% [markdown]
# We use early stopping to avoid over fitting

# %%
# model1.compile(loss="categorical_crossentropy", metrics=[Recall(thresholds=0.5)], optimizer='sgd')
# loss="categorical_crossentropy", 
#  loss="categorical_hinge",
# model1.compile( loss="categorical_crossentropy", metrics=['accuracy'], optimizer=optim )

model1.compile( loss="categorical_crossentropy", 
               metrics=metrics, 
               optimizer=optim )

history1 = model1.fit(  X_train, y_train, 
                        validation_data = (X_test, y_test), 
                        epochs=500, callbacks=[callback],
                      verbose=1)

# callbacks=[callback], 

# print(history1.history)
# Out:
# Epoch 1/500
# 27/27 [==============================] - 1s 8ms/step - loss: 1.3229 - f1-score: 0.5250 - val_loss: 1.1949 - val_f1-score: 0.0000e+00
# Epoch 2/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.9713 - f1-score: 0.5522 - val_loss: 0.9277 - val_f1-score: 0.3287
# Epoch 3/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.7503 - f1-score: 0.6159 - val_loss: 0.7572 - val_f1-score: 0.6239
# Epoch 4/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6150 - f1-score: 0.7028 - val_loss: 0.6443 - val_f1-score: 0.6877
# Epoch 5/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5186 - f1-score: 0.7439 - val_loss: 0.5733 - val_f1-score: 0.7145
# Epoch 6/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4397 - f1-score: 0.7753 - val_loss: 0.5146 - val_f1-score: 0.7188
# Epoch 7/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3007 - f1-score: 0.9248 - val_loss: 0.5862 - val_f1-score: 0.7188
# Epoch 8/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2697 - f1-score: 0.9321 - val_loss: 0.5808 - val_f1-score: 0.7188
# Epoch 9/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2697 - f1-score: 0.9276 - val_loss: 0.4447 - val_f1-score: 0.7188
# Epoch 10/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2453 - f1-score: 0.9323 - val_loss: 0.5280 - val_f1-score: 0.7188
# Epoch 11/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2375 - f1-score: 0.9308 - val_loss: 0.5048 - val_f1-score: 0.7188
# Epoch 12/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2160 - f1-score: 0.9314 - val_loss: 0.4536 - val_f1-score: 0.7188
# Epoch 13/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2239 - f1-score: 0.9290 - val_loss: 0.3705 - val_f1-score: 0.7476
# Epoch 14/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2154 - f1-score: 0.9273 - val_loss: 0.3269 - val_f1-score: 0.8745
# Epoch 15/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2014 - f1-score: 0.9355 - val_loss: 0.4469 - val_f1-score: 0.7188
# Epoch 16/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2037 - f1-score: 0.9371 - val_loss: 0.3738 - val_f1-score: 0.8080
# Epoch 17/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2125 - f1-score: 0.9208 - val_loss: 0.3699 - val_f1-score: 0.8599
# Epoch 18/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1926 - f1-score: 0.9301 - val_loss: 0.2729 - val_f1-score: 0.8856
# Epoch 19/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1839 - f1-score: 0.9330 - val_loss: 0.3359 - val_f1-score: 0.8326
# Epoch 20/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1795 - f1-score: 0.9303 - val_loss: 0.2500 - val_f1-score: 0.8790
# Epoch 21/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1856 - f1-score: 0.9256 - val_loss: 0.2910 - val_f1-score: 0.8745
# Epoch 22/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1799 - f1-score: 0.9270 - val_loss: 0.3359 - val_f1-score: 0.8207
# Epoch 23/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1650 - f1-score: 0.9344 - val_loss: 0.2815 - val_f1-score: 0.8632
# Epoch 24/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1581 - f1-score: 0.9363 - val_loss: 0.4895 - val_f1-score: 0.7534
# Epoch 25/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2079 - f1-score: 0.9196 - val_loss: 0.3028 - val_f1-score: 0.8669
# Epoch 26/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1646 - f1-score: 0.9299 - val_loss: 0.2441 - val_f1-score: 0.8846
# Epoch 27/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1623 - f1-score: 0.9284 - val_loss: 0.2113 - val_f1-score: 0.8844
# Epoch 28/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1641 - f1-score: 0.9329 - val_loss: 0.3000 - val_f1-score: 0.8653
# Epoch 29/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1598 - f1-score: 0.9271 - val_loss: 0.6063 - val_f1-score: 0.7188
# Epoch 30/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1819 - f1-score: 0.9187 - val_loss: 0.4757 - val_f1-score: 0.8197
# Epoch 31/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1509 - f1-score: 0.9341 - val_loss: 0.3547 - val_f1-score: 0.7800
# Epoch 32/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1619 - f1-score: 0.9252 - val_loss: 0.1920 - val_f1-score: 0.8779
# Epoch 33/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1513 - f1-score: 0.9343 - val_loss: 0.3433 - val_f1-score: 0.7892
# Epoch 34/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1432 - f1-score: 0.9329 - val_loss: 0.2120 - val_f1-score: 0.9183
# Epoch 35/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1385 - f1-score: 0.9343 - val_loss: 0.2047 - val_f1-score: 0.8885
# Epoch 36/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1312 - f1-score: 0.9318 - val_loss: 0.2211 - val_f1-score: 0.8728
# Epoch 37/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1373 - f1-score: 0.9321 - val_loss: 0.2233 - val_f1-score: 0.8778
# Epoch 38/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1189 - f1-score: 0.9390 - val_loss: 0.2234 - val_f1-score: 0.8778
# Epoch 39/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1311 - f1-score: 0.9388 - val_loss: 0.3371 - val_f1-score: 0.7769
# Epoch 40/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1239 - f1-score: 0.9452 - val_loss: 0.1910 - val_f1-score: 0.9307
# Epoch 41/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1232 - f1-score: 0.9401 - val_loss: 0.2319 - val_f1-score: 0.8599
# Epoch 42/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1324 - f1-score: 0.9340 - val_loss: 0.2407 - val_f1-score: 0.9327
# Epoch 43/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1131 - f1-score: 0.9470 - val_loss: 0.1829 - val_f1-score: 0.9221
# Epoch 44/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1503 - f1-score: 0.9273 - val_loss: 0.5129 - val_f1-score: 0.8701
# Epoch 45/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1369 - f1-score: 0.9336 - val_loss: 0.1754 - val_f1-score: 0.8934
# Epoch 46/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1126 - f1-score: 0.9400 - val_loss: 0.1569 - val_f1-score: 0.9361
# Epoch 47/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1469 - f1-score: 0.9435 - val_loss: 0.1543 - val_f1-score: 0.9437
# Epoch 48/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1369 - f1-score: 0.9399 - val_loss: 0.2147 - val_f1-score: 0.9358
# Epoch 49/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1222 - f1-score: 0.9404 - val_loss: 0.1545 - val_f1-score: 0.9396
# Epoch 50/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1326 - f1-score: 0.9415 - val_loss: 0.1620 - val_f1-score: 0.9461
# Epoch 51/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1378 - f1-score: 0.9355 - val_loss: 0.3579 - val_f1-score: 0.7498
# Epoch 52/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1255 - f1-score: 0.9399 - val_loss: 0.1652 - val_f1-score: 0.9301
# Epoch 53/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1020 - f1-score: 0.9610 - val_loss: 0.3596 - val_f1-score: 0.8226
# Epoch 54/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1175 - f1-score: 0.9534 - val_loss: 0.1707 - val_f1-score: 0.9305
# Epoch 55/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1355 - f1-score: 0.9374 - val_loss: 0.1567 - val_f1-score: 0.9365
# Epoch 56/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1114 - f1-score: 0.9467 - val_loss: 0.4030 - val_f1-score: 0.8534
# Epoch 57/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1386 - f1-score: 0.9398 - val_loss: 0.5350 - val_f1-score: 0.8606
# Epoch 58/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1417 - f1-score: 0.9363 - val_loss: 0.1742 - val_f1-score: 0.9469
# Epoch 59/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1142 - f1-score: 0.9503 - val_loss: 0.3741 - val_f1-score: 0.7309
# Epoch 60/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1401 - f1-score: 0.9446 - val_loss: 0.1955 - val_f1-score: 0.9341
# Epoch 61/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1345 - f1-score: 0.9378 - val_loss: 0.1665 - val_f1-score: 0.9201
# Epoch 62/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1095 - f1-score: 0.9488 - val_loss: 0.2699 - val_f1-score: 0.8415
# Epoch 63/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1137 - f1-score: 0.9467 - val_loss: 0.1610 - val_f1-score: 0.9332
# Epoch 64/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1047 - f1-score: 0.9498 - val_loss: 0.1617 - val_f1-score: 0.9328
# Epoch 65/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1185 - f1-score: 0.9522 - val_loss: 0.2114 - val_f1-score: 0.9325
# Epoch 66/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1262 - f1-score: 0.9367 - val_loss: 0.1768 - val_f1-score: 0.9227
# Epoch 67/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1137 - f1-score: 0.9539 - val_loss: 0.2159 - val_f1-score: 0.9209
# Epoch 68/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1342 - f1-score: 0.9322 - val_loss: 0.2890 - val_f1-score: 0.9138
# Epoch 69/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1368 - f1-score: 0.9463 - val_loss: 0.1887 - val_f1-score: 0.9463
# Epoch 70/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1261 - f1-score: 0.9353 - val_loss: 0.1470 - val_f1-score: 0.9426
# Epoch 71/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1205 - f1-score: 0.9511 - val_loss: 0.1698 - val_f1-score: 0.9381
# Epoch 72/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1105 - f1-score: 0.9537 - val_loss: 0.1705 - val_f1-score: 0.9305
# Epoch 73/500
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1253 - f1-score: 0.9481 - val_loss: 0.1733 - val_f1-score: 0.9312
# Epoch 73: early stopping

# %% [markdown]
# save the ANN classifier model for use later prediction

# %%
print(model1.summary())
filename = 'output/nn.sav'
pickle.dump(model1, open(filename,'wb'))
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 2)                 4
#
#  batch_normalization_4 (Batc  (None, 2)                8
#  hNormalization)
#
#  dense_9 (Dense)             (None, 3)                 9
#
# =================================================================
# Total params: 21
# Trainable params: 17
# Non-trainable params: 4
# _________________________________________________________________
# None
# INFO:tensorflow:Assets written to: ram://fd807f3a-a46b-4d67-a026-3c5a4775572e/assets

# %% [markdown]
# plot the training and validation test metric as a function of training epoch

# %%
plt.figure(figsize=(10,6))
# plt.plot(history1.history['accuracy'], linewidth=2)
# plt.plot(history1.history['val_accuracy'], linewidth=1)
###
# plt.plot( history1.history["recall"] )
# plt.plot( history1.history['val_recall'] )
###
plt.plot( history1.history["f1-score"])
plt.plot( history1.history['val_f1-score'] )
###
# plt.plot( history1.history["categorical_accuracy"] )
# plt.plot( history1.history['val_categorical_accuracy'] )
###
# plt.plot( history1.history["precision"] )
# plt.plot( history1.history['val_precision'] )
###
plt.grid(linestyle='--')
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.xlabel('epochs',fontsize=16)
# plt.ylabel('accuracy',fontsize=16)
# plt.ylabel('recall')
# plt.ylabel('categorical_accuracy')
# plt.ylabel("precision")
plt.ylabel("f1-score")
plt.show()

# %% [markdown]
# plot the training and validation test loss as a function of training epoch

# %%
plt.figure(figsize=(10,6))
plt.plot(history1.history['loss'], linewidth=2)
plt.plot(history1.history['val_loss'], linewidth=1 )
plt.grid(linestyle='--')
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.xlabel('epochs',fontsize=16)
plt.ylabel('loss',fontsize=16)
plt.show()

# %% [markdown]
# compute the confusion matrix from predictions

# %%
labels = lb.inverse_transform(y_test)
# print( type(labels), labels.shape )
y_pred = model1.predict(X_test)
# print( type(y_pred), y_pred.shape )
y_pred_labels = lb.inverse_transform(y_pred)
# print( type(y_pred_labels), y_pred_labels.shape )
#
cm = confusion_matrix( labels, y_pred_labels, num_classes=3 )
print(cm.numpy())
# Out:
# 18/18 [==============================] - 0s 916us/step
# [[432  26   6]
#  [  8  78   0]
#  [  1   0  25]]

# %% [markdown]
# plot the confusion matrix

# %%
class_labels = ['eq', 'ex', 'co']
# fig, ax = plt.subplots(figsize=(6,6))
plt.rcParams.update({'font.size': 22})
disp = ConfusionMatrixDisplay(confusion_matrix=cm.numpy(), display_labels=class_labels )
disp.plot()
plt.show()

# %% [markdown]
# ## We are going to append predictions to the original dataframe-X using all the classifiers/estimators and the write them out to be plotted on a sphere to see where the decision lines are placed.

# %% [markdown]
# the following function takes the loaded classifier and makes class membership predictions and class probabilities from the input features (in this case the features are synthetic)
#
# this function is for lune features

# %%
#
# load the classifier estimator and do predicts 
# (both class type and individual class probabilities)
# from a list of observed/measured or simulated features
# returns original dataframe with added columns: 
#      columns: class, etype_pred, prob_eq, prob_ex, prob_co 
#
import numpy as np

def physics_test_predict_lune( clf, X, class_labels ):
    # np.set_printoptions(precision=3, suppress=True)
    # np.set_printoptions(formatter={'float': '{: 0.2f}'.format})
    #
    nrows = len(X)
    probs = clf.predict(X)
    idx = np.argmax(probs,axis=1)
    
    etype = np.empty(nrows, dtype=object)
    for i in range(nrows):
        etype[i] = class_labels[int(idx[i])]
            
    X['class'] = idx[:]
    X['etype_pred'] = etype[:]
    X['prob_eq'] = probs[:,0]
    X['prob_ex'] = probs[:,1]
    X['prob_co'] = probs[:,2]
    # X['lune_lon'] = lune['lune_lon']
    # X['lune_lat'] = lune['lune_lat']

    return(X)

# %% [markdown]
# the function is similar to above but for testing the moment tensor features

# %%
#
# load the classifier estimator and do predicts 
# (both class type and individual class probabilities)
# from a list of observed/measured or simulated features
# returns original dataframe with added columns: 
#      columns: class, etype_pred, prob_eq, prob_ex, prob_co 
#
import numpy as np

def physics_test_predict_mt( clf, X, lune, class_labels ):
    # np.set_printoptions(precision=3, suppress=True)
    # np.set_printoptions(formatter={'float': '{: 0.2f}'.format})
    #
    nrows = len(X)
    probs = clf.predict(X)
    idx = np.argmax(probs,axis=1)
    
    etype = np.empty(nrows, dtype=object)
    for i in range(nrows):
        etype[i] = class_labels[int(idx[i])]
            
    X['class'] = idx[:]
    X['etype_pred'] = etype[:]
    X['prob_eq'] = probs[:,0]
    X['prob_ex'] = probs[:,1]
    X['prob_co'] = probs[:,2]
    X['lune_lon'] = lune['lune_lon']
    X['lune_lat'] = lune['lune_lat']

    return(X)

# %% [markdown]
# ### We loaded a sest of 50,005 precomputed lune_lon, and lune_lat features.  These were uniformly distributed on an eigenvalue sphere.  The values were simulate using a C-code.

# %%
df_syn = pd.read_csv( "data/lune2mt.csv")    
df_syn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50005 entries, 0 to 50004
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   lune_lon  50005 non-null  float64
#  1   lune_lat  50005 non-null  float64
#  2   pvr       50005 non-null  float64
#  3   pdc       50005 non-null  float64
#  4   pclvd     50005 non-null  float64
#  5   piso      50005 non-null  float64
#  6   Mo        50005 non-null  float64
#  7   mxx       50005 non-null  float64
#  8   myy       50005 non-null  float64
#  9   mzz       50005 non-null  float64
#  10  mxy       50005 non-null  float64
#  11  mxz       50005 non-null  float64
#  12  myz       50005 non-null  float64
#  13  eig1      50005 non-null  float64
#  14  eig2      50005 non-null  float64
#  15  eig3      50005 non-null  float64
# dtypes: float64(16)
# memory usage: 6.1 MB

# %%
# features = ['mxx', 'myy', 'mzz', 'mxy', 'mxz', 'myz']
features_lune = ['lune_lat', 'lune_lon']
X_synth = df_syn[features_lune]
#
class_labels = ['eq', 'ex', 'co']
df_lune = df_syn[['lune_lon', 'lune_lat']]
# df_lune.info()

# %% [markdown]
# ## We are going to append predictions to the original dataframe-X using all the classifiers/estimators and the write them out to be plotted on a sphere to see where the decision lines are placed.

# %%
filename = 'output/nn.sav'
load_nn = pickle.load(open(filename, 'rb'))
features_lune = ['lune_lat', 'lune_lon']
features_mt = ['mxx', 'myy', 'mzz', 'mxy', 'mxz', 'myz']
X_synth = df_syn[features_lune]
# X_new = physics_test_predict_mt( load_nn, X_synth, df_lune, class_labels )
X_new = physics_test_predict_lune( load_nn, X_synth, class_labels )
X_new.to_csv('output/nn.lune.csv', index=False)  
# X_new
# Out:
# 1563/1563 [==============================] - 1s 637us/step

# %% [markdown]
# ![Lune plot for ANN](output/nn.lune.lune.jpg)

# %% [markdown]
# ### go to output directory and use C-sh script to plot the output
